# %% [markdown]
# # Global Power Plant Database

# %%
# Importing required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#loading Dataset
df=pd.read_csv("global_power_plant_database.csv")
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %% [markdown]
# columns:
# 1. `country` (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5]
# 2. `country_long` (text): longer form of the country designation
# 3. `name` (text): name or title of the power plant, generally in Romanized form
# 4. `gppd_idnr` (text): 10 or 12 character identifier for the power plant
# 5. `capacity_mw` (number): electrical generating capacity in megawatts
# 6. `latitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
# 7. `longitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
# 8. `primary_fuel` (text): energy source used in primary electricity generation or export
# 9. `other_fuel1` (text): energy source used in electricity generation or export
# 10. `other_fuel2` (text): energy source used in electricity generation or export
# 11. `other_fuel3` (text): energy source used in electricity generation or export
# 12.  `commissioning_year` (number): year of plant operation, weighted by unit-capacity when data is available
# 13. `owner` (text): majority shareholder of the power plant, generally in Romanized form
# 14. `source` (text): entity reporting the data; could be an organization, report, or document, generally in Romanized form
# 15. `url` (text): web document corresponding to the `source` field
# 16. `geolocation_source` (text): attribution for geolocation information
# 17. `wepp_id` (text): a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
# 18. `year_of_capacity_data` (number): year the capacity information was reported
# 19. `generation_gwh_2013` (number): electricity generation in gigawatt-hours reported for the year 2013
# 20. `generation_gwh_2014` (number): electricity generation in gigawatt-hours reported for the year 2014
# 21. `generation_gwh_2015` (number): electricity generation in gigawatt-hours reported for the year 2015
# 22 `generation_gwh_2016` (number): electricity generation in gigawatt-hours reported for the year 2016
# 23. `generation_gwh_2017` (number): electricity generation in gigawatt-hours reported for the year 2017
# 24. `generation_gwh_2018` (number): electricity generation in gigawatt-hours reported for the year 2018
# 25. `generation_gwh_2019` (number): electricity generation in gigawatt-hours reported for the year 2019
# 26. `generation_data_source` (text): attribution for the reported generation information
# 27. `estimated_generation_gwh (number): estimated electricity generation in gigawatt-hours

# %%
# checking top rows of dataset
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
# checking bottam rows of dataset
df.tail()
# Out:
#     country country_long                          name   gppd_idnr  \
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 902       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 903          3.0   12.8932    78.1654        Solar         NaN         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      ...  year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
#checking sample of dataset
df.sample()
# Out:
#     country country_long                 name   gppd_idnr  capacity_mw  \
# 863     IND        India  Udumalpet Wind Farm  WRI1026066         25.7
#
#      latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 863   10.6143     77.237         Wind         NaN         NaN  ...
#
#      year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 863                    NaN                  NaN                 NaN
#
#     generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 863                 NaN                 NaN                 NaN
#
#      generation_gwh_2018  generation_gwh_2019  generation_data_source  \
# 863                  NaN                  NaN                     NaN
#
#      estimated_generation_gwh
# 863                       NaN
#
# [1 rows x 27 columns]

# %%
#checking number of unique values of dataset
df.nunique()
# Out:
# country                       1
# country_long                  1
# name                        907
# gppd_idnr                   907
# capacity_mw                 361
# latitude                    836
# longitude                   827
# primary_fuel                  8
# other_fuel1                   3
# other_fuel2                   1
# other_fuel3                   0
# commissioning_year           73
# owner                       280
# source                      191
# url                         304
# geolocation_source            3
# wepp_id                       0
# year_of_capacity_data         1
# generation_gwh_2013           0
# generation_gwh_2014         371
# generation_gwh_2015         396
# generation_gwh_2016         403
# generation_gwh_2017         408
# generation_gwh_2018         410
# generation_gwh_2019           0
# generation_data_source        1
# estimated_generation_gwh      0
# dtype: int64

# %%
# checking unique values of some column
df['country'].unique()
# Out:
# array(['IND'], dtype=object)

# %%
df['country_long'].unique()
# Out:
# array(['India'], dtype=object)

# %%
df['primary_fuel'].unique()
# Out:
# array(['Solar', 'Coal', 'Wind', 'Gas', 'Hydro', 'Biomass', 'Oil',
#        'Nuclear'], dtype=object)

# %%
df['other_fuel1'].unique()
# Out:
# array([nan, 'Oil', 'Cogeneration', 'Gas'], dtype=object)

# %%
df['other_fuel2'].unique()
# Out:
# array([nan, 'Oil'], dtype=object)

# %%
df['other_fuel3'].unique()
# Out:
# array([nan])

# %%
df['geolocation_source'].unique()
# Out:
# array(['National Renewable Energy Laboratory', 'WRI', nan,
#        'Industry About'], dtype=object)

# %%
df['wepp_id'].unique()
# Out:
# array([nan])

# %%
df['year_of_capacity_data'].unique()
# Out:
# array([  nan, 2019.])

# %%
df['generation_gwh_2013'].unique()
# Out:
# array([nan])

# %%
df['generation_gwh_2019'].unique()
# Out:
# array([nan])

# %%
df['generation_data_source'].unique()
# Out:
# array([nan, 'Central Electricity Authority'], dtype=object)

# %%
df['estimated_generation_gwh'].unique()
# Out:
# array([nan])

# %%
# droping irrevant column

df.drop("country",axis=1,inplace=True) 
df.drop("country_long",axis=1,inplace=True)
df.drop("other_fuel3",axis=1,inplace=True)
df.drop("wepp_id",axis=1,inplace=True)
df.drop("generation_gwh_2013",axis=1,inplace=True)
df.drop("generation_gwh_2019",axis=1,inplace=True)
df.drop("estimated_generation_gwh",axis=1,inplace=True)

# %%
df.drop("name",axis=1,inplace=True)
df.drop("gppd_idnr",axis=1,inplace=True)

# %%
df.drop("url",axis=1,inplace=True)

# %%
df.drop("other_fuel2",axis=1,inplace=True)

# %%
df.drop("generation_data_source",axis=1,inplace=True)

# %%
df.drop("owner",axis=1,inplace=True)

# %%
df.drop("year_of_capacity_data",axis=1,inplace=True)

# %%
df.drop("generation_gwh_2018",axis=1,inplace=True)

# %%
df.shape
# Out:
# (907, 12)

# %% [markdown]
# we have 907 rows and 12 columns in given dataset

# %%
#checking datatype
df.dtypes
# Out:
# capacity_mw            float64
# latitude               float64
# longitude              float64
# primary_fuel            object
# other_fuel1             object
# commissioning_year     float64
# source                  object
# geolocation_source      object
# generation_gwh_2014    float64
# generation_gwh_2015    float64
# generation_gwh_2016    float64
# generation_gwh_2017    float64
# dtype: object

# %%
#checking information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   capacity_mw          907 non-null    float64
#  1   latitude             861 non-null    float64
#  2   longitude            861 non-null    float64
#  3   primary_fuel         907 non-null    object
#  4   other_fuel1          198 non-null    object
#  5   commissioning_year   527 non-null    float64
#  6   source               907 non-null    object
#  7   geolocation_source   888 non-null    object
#  8   generation_gwh_2014  398 non-null    float64
#  9   generation_gwh_2015  422 non-null    float64
#  10  generation_gwh_2016  434 non-null    float64
#  11  generation_gwh_2017  440 non-null    float64
# dtypes: float64(8), object(4)
# memory usage: 85.2+ KB

# %%
# Checking null values in the dataset
df.isnull().sum()
# Out:
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# other_fuel1            709
# commissioning_year     380
# source                   0
# geolocation_source      19
# generation_gwh_2014    509
# generation_gwh_2015    485
# generation_gwh_2016    473
# generation_gwh_2017    467
# dtype: int64

# %% [markdown]
# lots of null values are present in all column except capacit , source and url

# %%
# Let's visualize the null values clearly
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# it shown clearly that lots of null values are present

# %% [markdown]
# ### treating null values

# %% [markdown]
# filling null values as mean and medium for numerical data and mode for categorical data

# %%
#checking the mean of latitude(numerical column)
df['latitude'].mean()
# Out:
# 21.19791811846691

# %%
#checking the mode of other_fuel1 (categorical column)
df["other_fuel1"].mode()
# Out:
# 0    Oil
# Name: other_fuel1, dtype: object

# %%
#checking the mode of geolocation_source columns(categorical column)
df["geolocation_source"].mode()
# Out:
# 0    WRI
# Name: geolocation_source, dtype: object

# %%
df["latitude"] = df["latitude"].fillna(df["latitude"].mean())
df["other_fuel1"] = df["other_fuel1"].fillna(df["other_fuel1"].mode()[0])
df["geolocation_source"] = df["geolocation_source"].fillna(df["geolocation_source"].mode()[0])
df["longitude"] = df["longitude"].fillna(df["longitude"].median())
df["commissioning_year"] = df["commissioning_year"].fillna(df["commissioning_year"].median())
df["generation_gwh_2014"] = df["generation_gwh_2014"].fillna(df["generation_gwh_2014"].median())
df["generation_gwh_2015"] = df["generation_gwh_2015"].fillna(df["generation_gwh_2015"].median())
df["generation_gwh_2016"] = df["generation_gwh_2016"].fillna(df["generation_gwh_2016"].median())
df["generation_gwh_2017"] = df["generation_gwh_2017"].fillna(df["generation_gwh_2017"].median())

# %%
# again checking null values in the dataset
df.isnull().sum()
# Out:
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# other_fuel1            0
# commissioning_year     0
# source                 0
# geolocation_source     0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# dtype: int64

# %%
# Let's again visualize the null values clearly
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# Checking the list of counts of capacity_mw(target 1)
df['capacity_mw'].value_counts()
# Out:
# 5.0       39
# 10.0      22
# 600.0     20
# 15.0      20
# 1200.0    19
#           ..
# 291.0      1
# 645.0      1
# 41.4       1
# 17.5       1
# 106.6      1
# Name: capacity_mw, Length: 361, dtype: int64

# %%
# Checking the list of counts of primary_fuel(target 2)
df['primary_fuel'].value_counts()
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %%
# Checking the uniqueness of primary_fuel
df["primary_fuel"].unique()
# Out:
# array(['Solar', 'Coal', 'Wind', 'Gas', 'Hydro', 'Biomass', 'Oil',
#        'Nuclear'], dtype=object)

# %% [markdown]
# no null value is present

# %%
# checking for white space
# Iterate through each column of the dataframe and check for white spaces
for col in df.columns:
    # Count the number of white spaces in the column
    num_spaces = sum(df[col].astype(str).apply(lambda x: x.isspace()))

    # Display the results
    print(f"Column '{col}' has {num_spaces} white spaces.")
# Out:
# Column 'capacity_mw' has 0 white spaces.
# Column 'latitude' has 0 white spaces.
# Column 'longitude' has 0 white spaces.
# Column 'primary_fuel' has 0 white spaces.
# Column 'other_fuel1' has 0 white spaces.
# Column 'commissioning_year' has 0 white spaces.
# Column 'source' has 0 white spaces.
# Column 'geolocation_source' has 0 white spaces.
# Column 'generation_gwh_2014' has 0 white spaces.
# Column 'generation_gwh_2015' has 0 white spaces.
# Column 'generation_gwh_2016' has 0 white spaces.
# Column 'generation_gwh_2017' has 0 white spaces.

# %% [markdown]
# no whilespaces is present in any column

# %%
# splitting the dataset in numerical and categorical dataset
# checking for categorical columns
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_col.append(i)
print(categorical_col)
# Out:
# ['primary_fuel', 'other_fuel1', 'source', 'geolocation_source']

# %%
# Now checking for numerical columns
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_col.append(i)
print(numerical_col)
# Out:
# ['capacity_mw', 'latitude', 'longitude', 'commissioning_year', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017']

# %% [markdown]
# ### Visualization

# %% [markdown]
# ### univariant visualization

# %%
plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
# Add axis labels and title
plt.xlabel('primary_fuel')
plt.ylabel('Count')
sns.countplot(df["primary_fuel"])

plt.subplot(2,2,2)
# Add axis labels and title
plt.xlabel('other_fuel1')
plt.ylabel('Count')
sns.countplot(df["other_fuel1"])


plt.subplot(2,2,3)
# Add axis labels and title
plt.xlabel('source')
plt.ylabel('Count')
sns.countplot(df["source"])


plt.subplot(2,2,4)
# Add axis labels and title
plt.xlabel('geolocation_source')
plt.ylabel('Count')
sns.countplot(df["geolocation_source"])

# Display the plot
plt.show()

# %% [markdown]
# observation:
# 1. coal is used as primary fuel most followed by hydro, solar, wind, gas biomas.
# 2. Oil is used as an other fuel most
# 3. WRI is used as a geolocation source most

# %%
# Checking how the data has been distriubted in each column

plt.figure(figsize=(10,10),facecolor='white')
plotnumber=1
for column in numerical_col:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column],color="b")
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Observation :
#     I observed that data is not normally distributed

# %% [markdown]
# ### Bivariant analysis for target 1 (capacity_mw )

# %%
#Checking the relation between latitude and capacity_mw
plt.figure(figsize=[6,3])
plt.title('Comparision between latitude and capacity_mw')
sns.scatterplot(df['latitude'],df["capacity_mw"])
# Out:
# <AxesSubplot:title={'center':'Comparision between latitude and capacity_mw'}, xlabel='latitude', ylabel='capacity_mw'>

# %% [markdown]
# I found no relationship

# %%
#Checking the relation between capacity_mw and variable geolocation source
plt.figure(figsize=[6,3])
plt.style.use('ggplot')
plt.title('Comparision between geolocation_source and capacity_mw')
sns.barplot(df['geolocation_source'],df["capacity_mw"])
# Out:
# <AxesSubplot:title={'center':'Comparision between geolocation_source and capacity_mw'}, xlabel='geolocation_source', ylabel='capacity_mw'>

# %% [markdown]
# WRI has high capacity followed by national renewable energy laboratory

# %%
#Checking the relation between longitude and capacity_mw
plt.figure(figsize=[6,3])
plt.title('Comparision between longitude and capacity_mw')
sns.lineplot(df['longitude'],df["capacity_mw"])
# Out:
# <AxesSubplot:title={'center':'Comparision between longitude and capacity_mw'}, xlabel='longitude', ylabel='capacity_mw'>

# %% [markdown]
# here doesn't find any relationship

# %%
#Checking the relation between primary_fuel and capacity_mw
plt.figure(figsize=[6,3])
plt.title('Comparision between primary_fuel and capacity_mw')
sns.lineplot(df['primary_fuel'],df["capacity_mw"])
# Out:
# <AxesSubplot:title={'center':'Comparision between primary_fuel and capacity_mw'}, xlabel='primary_fuel', ylabel='capacity_mw'>

# %% [markdown]
# Primary fuel as nuclear has more capacity followed by coal and gas

# %%
#Checking the relation between other_fuel1 and capacity_mw
plt.figure(figsize=[6,3])
plt.title('Comparision between other_fuel1 and capacity_mw')
sns.barplot(df['other_fuel1'],df["capacity_mw"])
# Out:
# <AxesSubplot:title={'center':'Comparision between other_fuel1 and capacity_mw'}, xlabel='other_fuel1', ylabel='capacity_mw'>

# %% [markdown]
# Oil and gas has higher capacity

# %%
#Checking the relation between commissioning_year and capacity_mw
plt.figure(figsize=[6,3])
plt.title('Comparision between commissioning_year and capacity_mw')
sns.regplot(df['commissioning_year'],df["capacity_mw"])
# Out:
# <AxesSubplot:title={'center':'Comparision between commissioning_year and capacity_mw'}, xlabel='commissioning_year', ylabel='capacity_mw'>

# %% [markdown]
# capacity is increasing year by year

# %%
#Checking the relation between source and capacity_mw
plt.figure(figsize=[6,3])
plt.title('Comparision between source and capacity_mw')
sns.scatterplot(df['source'],df["capacity_mw"])
# Out:
# <AxesSubplot:title={'center':'Comparision between source and capacity_mw'}, xlabel='source', ylabel='capacity_mw'>

# %%
#Checking the relation between generation_gwh_2014 and capacity_mw
plt.figure(figsize=[6,3])
plt.title('Comparision between generation_gwh_2014 and capacity_mw')
sns.lineplot(df['generation_gwh_2014'],df["capacity_mw"])
# Out:
# <AxesSubplot:title={'center':'Comparision between generation_gwh_2014 and capacity_mw'}, xlabel='generation_gwh_2014', ylabel='capacity_mw'>

# %% [markdown]
# capacity increases as generation increases

# %%
#Checking the relation between generation_gwh_2015 and capacity_mw
plt.figure(figsize=[6,3])
plt.title('Comparision between generation_gwh_2015 and capacity_mw')
sns.lineplot(df['generation_gwh_2015'],df["capacity_mw"])
# Out:
# <AxesSubplot:title={'center':'Comparision between generation_gwh_2015 and capacity_mw'}, xlabel='generation_gwh_2015', ylabel='capacity_mw'>

# %% [markdown]
# capacity increases as generation increases

# %%
#Checking the relation between generation_gwh_2016 and capacity_mw
plt.figure(figsize=[6,3])
plt.title('Comparision between generation_gwh_2016 and capacity_mw')
sns.lineplot(df['generation_gwh_2016'],df["capacity_mw"])
# Out:
# <AxesSubplot:title={'center':'Comparision between generation_gwh_2016 and capacity_mw'}, xlabel='generation_gwh_2016', ylabel='capacity_mw'>

# %% [markdown]
# capacity increases as generation increases

# %%
#Checking the relation between generation_gwh_2017 and capacity_mw
plt.figure(figsize=[6,3])
plt.title('Comparision between generation_gwh_2017 and capacity_mw')
sns.lineplot(df['generation_gwh_2017'],df["capacity_mw"])
# Out:
# <AxesSubplot:title={'center':'Comparision between generation_gwh_2017 and capacity_mw'}, xlabel='generation_gwh_2017', ylabel='capacity_mw'>

# %% [markdown]
# capacity increases as generation increases

# %% [markdown]
# ### Bivariant analysis for target 2 (primary_fuel )

# %%
#Checking the relation between capacity_mw and primary_fuel
plt.figure(figsize=[6,3])
plt.title('Comparision between capacity_mw and primary_fuel')
sns.barplot(df['capacity_mw'],df["primary_fuel"])
# Out:
# <AxesSubplot:title={'center':'Comparision between capacity_mw and primary_fuel'}, xlabel='capacity_mw', ylabel='primary_fuel'>

# %% [markdown]
# nuclear has higher capacity then followed by coal,gas, hydro

# %%
#Checking the relation between latitude and primary_fuel
plt.figure(figsize=[6,3])
plt.title('Comparision between latitude and primary_fuel')
sns.barplot(df['latitude'],df["primary_fuel"])
# Out:
# <AxesSubplot:title={'center':'Comparision between latitude and primary_fuel'}, xlabel='latitude', ylabel='primary_fuel'>

# %% [markdown]
# solar has higher lattitude followed by hydro

# %%
#Checking the relation between longitude and primary_fuel
plt.figure(figsize=[6,3])
plt.title('Comparision between longitude and primary_fuel')
sns.barplot(df['longitude'],df["primary_fuel"])
# Out:
# <AxesSubplot:title={'center':'Comparision between longitude and primary_fuel'}, xlabel='longitude', ylabel='primary_fuel'>

# %% [markdown]
# coal uses higher and gas and hydro uses almost same in longitude

# %%
#Checking the relation between other_fuel1 and primary_fuel
plt.figure(figsize=[6,3])
plt.title('Comparision between other_fuel1 and primary_fuel')
sns.lineplot(df['other_fuel1'],df["primary_fuel"])
# Out:
# <AxesSubplot:title={'center':'Comparision between other_fuel1 and primary_fuel'}, xlabel='other_fuel1', ylabel='primary_fuel'>

# %% [markdown]
# no relationship found

# %%
#Checking the relation between commissioning_year and primary_fuel
plt.figure(figsize=[6,3])
plt.title('Comparision between commissioning_year and primary_fuel')
sns.lineplot(df['commissioning_year'],df["primary_fuel"])
# Out:
# <AxesSubplot:title={'center':'Comparision between commissioning_year and primary_fuel'}, xlabel='commissioning_year', ylabel='primary_fuel'>

# %% [markdown]
# no relationship found

# %%
#Checking the relation between source and primary_fuel
plt.figure(figsize=[6,3])
plt.title('Comparision between source and primary_fuel')
sns.scatterplot(df['source'],df["primary_fuel"])
# Out:
# <AxesSubplot:title={'center':'Comparision between source and primary_fuel'}, xlabel='source', ylabel='primary_fuel'>

# %%
#Checking the relation between geolocation_source and primary_fuel
plt.figure(figsize=[6,3])
plt.title('Comparision between geolocation_source and primary_fuel')
sns.lineplot(df['geolocation_source'],df["primary_fuel"])
# Out:
# <AxesSubplot:title={'center':'Comparision between geolocation_source and primary_fuel'}, xlabel='geolocation_source', ylabel='primary_fuel'>

# %% [markdown]
# no relationship found

# %%
#Checking the relation between generation_gwh_2014 and primary_fuel
plt.figure(figsize=[6,3])
plt.title('Comparision between generation_gwh_2014 and primary_fuel')
sns.barplot(df['generation_gwh_2014'],df["primary_fuel"])
# Out:
# <AxesSubplot:title={'center':'Comparision between generation_gwh_2014 and primary_fuel'}, xlabel='generation_gwh_2014', ylabel='primary_fuel'>

# %% [markdown]
# nuclear has higher generation in 2014

# %%
#Checking the relation between generation_gwh_2015 and primary_fuel
plt.figure(figsize=[6,3])
plt.title('Comparision between generation_gwh_2015 and primary_fuel')
sns.barplot(df['generation_gwh_2015'],df["primary_fuel"])
# Out:
# <AxesSubplot:title={'center':'Comparision between generation_gwh_2015 and primary_fuel'}, xlabel='generation_gwh_2015', ylabel='primary_fuel'>

# %% [markdown]
# nuclear has higher generation in 2015

# %%
#Checking the relation between generation_gwh_2016 and primary_fuel
plt.figure(figsize=[6,3])
plt.title('Comparision between generation_gwh_2016 and primary_fuel')
sns.barplot(df['generation_gwh_2016'],df["primary_fuel"])
# Out:
# <AxesSubplot:title={'center':'Comparision between generation_gwh_2016 and primary_fuel'}, xlabel='generation_gwh_2016', ylabel='primary_fuel'>

# %% [markdown]
# nuclear has higher generation in 2016

# %%
#Checking the relation between generation_gwh_2017 and primary_fuel
plt.figure(figsize=[6,3])
plt.title('Comparision between generation_gwh_2017 and primary_fuel')
sns.barplot(df['generation_gwh_2017'],df["primary_fuel"])
# Out:
# <AxesSubplot:title={'center':'Comparision between generation_gwh_2017 and primary_fuel'}, xlabel='generation_gwh_2017', ylabel='primary_fuel'>

# %% [markdown]
# nuclear has higher generation in 2017

# %% [markdown]
# ### statistical summary

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  commissioning_year  \
# count   907.000000  907.000000  907.000000          907.000000
# mean    326.223755   21.197918   77.427103         1998.728776
# std     590.085456    6.079148    4.815073           13.158621
# min       0.000000    8.168900   68.644700         1927.000000
# 25%      16.725000   17.072000   74.388900         1998.000000
# 50%      59.200000   21.281800   76.719500         2001.000000
# 75%     385.250000   25.176450   79.206100         2003.000000
# max    4760.000000   34.649000   95.408000         2018.000000
#
#        generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# count           907.000000           907.000000           907.000000
# mean           1516.689956          1510.071296          1565.361383
# std            2785.604307          2984.994556          3005.087210
# min               0.000000             0.000000             0.000000
# ...

# %% [markdown]
# Observation:
# 1. count is same for all columns
# 2. mean >median in capacity_mw,generation_gwh_2014,	generation_gwh_2015,	generation_gwh_2016,	generation_gwh_2017 so data is left skewed.

# %%
# statistical summary of categorical columns
df.describe(include=['O'])
# Out:
#        primary_fuel other_fuel1                         source  \
# count           907         907                            907
# unique            8           3                            191
# top            Coal         Oil  Central Electricity Authority
# freq            258         904                            519
#
#        geolocation_source
# count                 907
# unique                  3
# top                   WRI
# freq                  784

# %%
# visualize df.describe
plt.figure(figsize=(22,15))
sns.heatmap(df.describe(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
#converting categorical data into numerical data
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cols=['primary_fuel', 'other_fuel1', 'source', 'geolocation_source']
df[cols] = df[cols].apply(LabelEncoder().fit_transform)
df
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            2
# 1           98.0   24.7663    74.6090             1            2
# 2           39.2   21.9038    69.3732             7            2
# 3          135.0   23.8712    91.3602             2            2
# 4         1800.0   21.9603    82.4091             1            2
# ..           ...       ...        ...           ...          ...
# 902       1600.0   16.2949    77.3568             1            2
# 903          3.0   12.8932    78.1654             6            2
# 904         25.5   15.2758    75.5811             7            2
# 905         80.0   24.3500    73.7477             1            2
# 906         16.5    9.9344    77.4768             7            2
#
#      commissioning_year  source  geolocation_source  generation_gwh_2014  \
# 0                2011.0     109                   1           801.123775
# ...

# %%
#  again visualize df.describe
plt.figure(figsize=(22,15))
sns.heatmap(df.describe(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
#correlation
df.corr()
# Out:
#                      capacity_mw  latitude  longitude  primary_fuel  \
# capacity_mw             1.000000  0.050984   0.199299     -0.380395
# latitude                0.050984  1.000000   0.036341     -0.010204
# longitude               0.199299  0.036341   1.000000     -0.352056
# primary_fuel           -0.380395 -0.010204  -0.352056      1.000000
# other_fuel1             0.003105  0.036695   0.029867      0.004912
# commissioning_year      0.211042  0.087937   0.029583     -0.054885
# source                 -0.242122  0.055927  -0.236623      0.053613
# geolocation_source      0.204865 -0.184275   0.249100     -0.483217
# generation_gwh_2014     0.793497  0.058594   0.106855     -0.240656
# generation_gwh_2015     0.819676  0.053869   0.123763     -0.249304
# generation_gwh_2016     0.853008  0.047677   0.145640     -0.259708
# generation_gwh_2017     0.868338  0.057897   0.154014     -0.263599
#
#                      other_fuel1  commissioning_year    source  \
# ...

# %%
# visualize the correlation
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),linewidths=0.1,fmt='0.2f',annot=True)
# Out:
# <AxesSubplot:>

# %%
# correlation of column with target column
df.corr()["capacity_mw"].sort_values()
# Out:
# primary_fuel          -0.380395
# source                -0.242122
# other_fuel1            0.003105
# latitude               0.050984
# longitude              0.199299
# geolocation_source     0.204865
# commissioning_year     0.211042
# generation_gwh_2014    0.793497
# generation_gwh_2015    0.819676
# generation_gwh_2016    0.853008
# generation_gwh_2017    0.868338
# capacity_mw            1.000000
# Name: capacity_mw, dtype: float64

# %%
plt.figure(figsize=(22,7))
df.corr()['capacity_mw'].sort_values(ascending=False).drop(['capacity_mw']).plot(kind='bar')
plt.xlabel('Values',fontsize=14)
plt.ylabel('capacity_mw',fontsize=14)
plt.title('corelation',fontsize=16)
plt.show()

# %% [markdown]
# capacity has
# 1. positive correlation with generation from year 2014 to 2017, geolocation source longitute, lattitude and other fuel
# 2. negative corelation with source and primary fuel

# %%
# correlation of column with target column
df.corr()["primary_fuel"].sort_values()
# Out:
# geolocation_source    -0.483217
# capacity_mw           -0.380395
# longitude             -0.352056
# generation_gwh_2017   -0.263599
# generation_gwh_2016   -0.259708
# generation_gwh_2015   -0.249304
# generation_gwh_2014   -0.240656
# commissioning_year    -0.054885
# latitude              -0.010204
# other_fuel1            0.004912
# source                 0.053613
# primary_fuel           1.000000
# Name: primary_fuel, dtype: float64

# %%
plt.figure(figsize=(22,7))
df.corr()['primary_fuel'].sort_values(ascending=False).drop(['primary_fuel']).plot(kind='bar')
plt.xlabel('Values',fontsize=14)
plt.ylabel('primary_fuel',fontsize=14)
plt.title('corelation',fontsize=16)
plt.show()

# %% [markdown]
# primary fuel has
# 1. positive correlation with source and other fuel
# 2. negative corelation with generation from year 2014 to 2017, geolocation source, longitute, lattitude and capacity

# %%
# skewness
df.skew()
# Out:
# capacity_mw             3.123576
# latitude               -0.149698
# longitude               1.163320
# primary_fuel            0.472251
# other_fuel1           -20.453120
# commissioning_year     -1.719575
# source                  1.827373
# geolocation_source     -2.159841
# generation_gwh_2014     5.321360
# generation_gwh_2015     5.566773
# generation_gwh_2016     5.281953
# generation_gwh_2017     5.315103
# dtype: float64

# %%
# checking for outliers

numerical_col=df[numerical_col]
plt.figure(figsize=(20,18))
for i, column in enumerate(numerical_col, 1):
    plt.subplot(4,4,i)
    sns.boxplot(df[column])

# %% [markdown]
# in most of the columns outlier present

# %%
# Features containing outliers
features = df[['longitude', 'latitude', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017','commissioning_year']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))

z
# Out:
#      longitude  latitude  generation_gwh_2014  generation_gwh_2015  \
# 0     0.869917  1.149805             0.257022             0.267783
# 1     0.585590  0.587311             0.257022             0.267783
# 2     1.673567  0.116179             0.257022             0.267783
# 3     2.895239  0.439989             0.322873             0.223348
# 4     1.035238  0.125479             0.545554             1.476964
# ..         ...       ...                  ...                  ...
# 902   0.014609  0.806975             0.257022             0.505833
# 903   0.153415  1.366853             0.257022             0.267783
# 904   0.383592  0.974707             0.257022             0.267783
# 905   0.764564  0.518793             0.257022             0.267783
# 906   0.010327  1.853834             0.257022             0.267783
#
#      generation_gwh_2016  generation_gwh_2017  commissioning_year
# 0               0.275737             0.275565            0.933076
# ...

# %%
# Creating new dataframe
new_df = df[(z<3).all(axis=1)] 
new_df
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            2
# 1           98.0   24.7663    74.6090             1            2
# 2           39.2   21.9038    69.3732             7            2
# 3          135.0   23.8712    91.3602             2            2
# 4         1800.0   21.9603    82.4091             1            2
# ..           ...       ...        ...           ...          ...
# 902       1600.0   16.2949    77.3568             1            2
# 903          3.0   12.8932    78.1654             6            2
# 904         25.5   15.2758    75.5811             7            2
# 905         80.0   24.3500    73.7477             1            2
# 906         16.5    9.9344    77.4768             7            2
#
#      commissioning_year  source  geolocation_source  generation_gwh_2014  \
# 0                2011.0     109                   1           801.123775
# ...

# %%
new_df.shape
# Out:
# (852, 12)

# %%
#data loss in percentage
Data_loss =((df.shape[0]-new_df.shape[0])/df.shape[0])*100
Data_loss
# Out:
# 6.063947078280044

# %% [markdown]
# here % loss is not greater than 10% so we can accept this value

# %%
#checking skewness for new dataset
new_df.skew()
# Out:
# capacity_mw             2.185823
# latitude               -0.119663
# longitude               0.944167
# primary_fuel            0.415658
# other_fuel1           -19.820871
# commissioning_year     -1.279935
# source                  1.736117
# geolocation_source     -2.068499
# generation_gwh_2014     2.941090
# generation_gwh_2015     2.714849
# generation_gwh_2016     2.634502
# generation_gwh_2017     2.531497
# dtype: float64

# %%
# Removing skewness using yeo-johnson  method to get better prediction
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
new_df = scaler.fit_transform(new_df)

# %%
new_df= pd.DataFrame(new_df)

# %%
new_df.skew()
# Out:
# 0      0.016478
# 1     -0.069190
# 2     -0.000209
# 3     -0.057536
# 4    -16.792739
# 5     -0.317424
# 6     -0.173813
# 7     -2.041749
# 8      0.231858
# 9      0.163407
# 10     0.145702
# 11     0.126375
# dtype: float64

# %% [markdown]
# skewness was almost reduce

# %%
new_df=df

# %% [markdown]
# ## prediction for target 1(capacity_mw)

# %%
x=df.drop('capacity_mw', axis=1)
y=df["capacity_mw"]

# %%
x.shape
# Out:
# (907, 11)

# %%
y.shape
# Out:
# (907,)

# %% [markdown]
# ### scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#      latitude  longitude  primary_fuel  other_fuel1  commissioning_year  \
# 0    1.149805  -0.869917      1.225688     0.054303            0.933076
# 1    0.587311  -0.585590     -0.967877     0.054303            0.172699
# 2    0.116179  -1.673567      1.664401     0.054303            0.172699
# 3    0.439989   2.895239     -0.529164     0.054303            0.400812
# 4    0.125479   1.035238     -0.967877     0.054303            1.237227
# ..        ...        ...           ...          ...                 ...
# 902 -0.806975  -0.014609     -0.967877     0.054303            1.313265
# 903 -1.366853   0.153415      1.225688     0.054303            0.172699
# 904 -0.974707  -0.383592      1.664401     0.054303            0.172699
# 905  0.518793  -0.764564     -0.967877     0.054303            0.172699
# 906 -1.853834   0.010327      1.664401     0.054303            0.172699
#
#        source  geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# ...

# %% [markdown]
# ### Checking VIF Values

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#     VIF values             Features
# 0     1.069408             latitude
# 1     1.225372            longitude
# 2     1.677613         primary_fuel
# 3     1.005449          other_fuel1
# 4     1.076808   commissioning_year
# 5     1.559601               source
# 6     1.987133   geolocation_source
# 7    14.264396  generation_gwh_2014
# 8    34.029368  generation_gwh_2015
# 9    44.046909  generation_gwh_2016
# 10   20.034783  generation_gwh_2017

# %%
x.drop("commissioning_year", axis=1, inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#    VIF values             Features
# 0    1.064425             latitude
# 1    1.225251            longitude
# 2    1.675991         primary_fuel
# 3    1.004345          other_fuel1
# 4    1.549723               source
# 5    1.984431   geolocation_source
# 6   14.114753  generation_gwh_2014
# 7   34.011924  generation_gwh_2015
# 8   43.884029  generation_gwh_2016
# 9   19.975996  generation_gwh_2017

# %%
x.drop("generation_gwh_2016", axis=1, inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#    VIF values             Features
# 0    1.060736             latitude
# 1    1.223683            longitude
# 2    1.675785         primary_fuel
# 3    1.003831          other_fuel1
# 4    1.549628               source
# 5    1.983858   geolocation_source
# 6   14.090387  generation_gwh_2014
# 7   22.130074  generation_gwh_2015
# 8    8.777196  generation_gwh_2017

# %%
x.drop("generation_gwh_2015", axis=1, inplace=True)

# %%
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#    VIF values             Features
# 0    1.060309             latitude
# 1    1.223641            longitude
# 2    1.675779         primary_fuel
# 3    1.003801          other_fuel1
# 4    1.549535               source
# 5    1.983857   geolocation_source
# 6    5.520406  generation_gwh_2014
# 7    5.620388  generation_gwh_2017

# %% [markdown]
# multicooliarity removed

# %%
y.nunique()
# Out:
# 361

# %%
y.dtype
# Out:
# dtype('float64')

# %% [markdown]
# It is a type of linear regration

# %% [markdown]
# ### modelling

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
lr=LinearRegression()

# %%
best_random_state = None
best_testing_accuracy = 0

for i in range(0, 100):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=i)
    lr.fit(x_train, y_train)
    pred_test = lr.predict(x_test)
    testing_accuracy = r2_score(y_test, pred_test)
    
    if testing_accuracy > best_testing_accuracy:
        best_testing_accuracy = testing_accuracy
        best_random_state = i

print("Best random state:", best_random_state)
print("Best testing accuracy:", best_testing_accuracy)
# Out:
# Best random state: 15
# Best testing accuracy: 0.8870929720403901

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=15)

# %%
#train the model
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# prediction
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

pred_train=lr.predict(x_train)
pred_test=lr.predict(x_test)
print('R2_score:',r2_score(y_test,pred_test))


print("Errors")
# Mean Absolute Error (MAE)
print('MAE:',mean_absolute_error(y_test, pred_test))

# Mean Squared Error (MSE)
print('MSE:',mean_squared_error(y_test, pred_test))

# Root Mean Squared Error (RMSE)
print("RMSE:",np.sqrt(mean_squared_error(y_test, pred_test)))
# Out:
# R2_score: 0.8870929720403901
# Errors
# MAE: 136.754905123456
# MSE: 44623.67777578594
# RMSE: 211.2431721400385

# %%
from sklearn.model_selection import cross_val_score
train_accuracy=r2_score(y_train,pred_train)
test_accuracy=r2_score(y_test,pred_test)
cv_scores = []
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.7581883173997849 and accuracy score for training is 0.7663096191092329 and accuracy for testing is 0.8870929720403901
#
#
# At cross fold 3 the cv score is 0.7713477376586478 and accuracy score for training is 0.7663096191092329 and accuracy for testing is 0.8870929720403901
#
#
# At cross fold 4 the cv score is 0.7705330310052722 and accuracy score for training is 0.7663096191092329 and accuracy for testing is 0.8870929720403901
#
#
# At cross fold 5 the cv score is 0.7817067685917729 and accuracy score for training is 0.7663096191092329 and accuracy for testing is 0.8870929720403901
#
#
# At cross fold 6 the cv score is 0.7723660678281812 and accuracy score for training is 0.7663096191092329 and accuracy for testing is 0.8870929720403901
#
#
# At cross fold 7 the cv score is 0.7753153342455034 and accuracy score for training is 0.7663096191092329 and accuracy for testing is 0.8870929720403901
#
#
# ...

# %% [markdown]
# we select cv=5

# %%
print(cross_val_score(lr,x,y,cv=5).mean())
# Out:
# 0.7817067685917729

# %% [markdown]
# ### Lasso regressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn .linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}

# %%
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha= 10, random_state= 0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
print("r2 score",lss)
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
print("cross val score",cv_mean)
# Out:
# r2 score 0.8839245795053827
# cross val score 0.7823987133505754

# %% [markdown]
# ### RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Checking R2 score for  Random Forest Regressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)

# prediction
pred_rf=rf.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_rf))

# Mean Absolute Error (MAE)
print('MAE:',mean_absolute_error(y_test, pred_rf))

# Mean Squared Error (MSE)
print('MSE:',mean_squared_error(y_test, pred_rf))

# Root Mean Squared Error (RMSE)
print("RMSE:",np.sqrt(mean_squared_error(y_test, pred_rf)))

# Checking cv score for Random Forest Regression
print("Cross_Validaton_Score",cross_val_score(rf,x,y,cv=5).mean())
# Out:
# R2_Score: 0.8781517102837318
# MAE: 109.49728561083984
# MSE: 48157.487767497034
# RMSE: 219.44814368660545
# Cross_Validaton_Score 0.8183613892085317

# %% [markdown]
# ### KNeighborsRegressor

# %%
# Checking R2 score for KNN Regressor
from sklearn.neighbors import KNeighborsRegressor as KNN
knn=KNN()
knn.fit(x_train,y_train)

# prediction
predknn=knn.predict(x_test)
print('R2_Score:',r2_score(y_test,predknn))
print('MAE:',mean_absolute_error(y_test, predknn))
print('MSE:',mean_squared_error(y_test, predknn))
print("RMSE:",np.sqrt(mean_squared_error(y_test, predknn)))

# Checking cv score for KNN
print("Cross_Validaton_Score",cross_val_score(knn,x,y,cv=5).mean())
# Out:
# R2_Score: 0.8674379578907994
# MAE: 119.17188131868132
# MSE: 52391.830334044826
# RMSE: 228.8926174738819
# Cross_Validaton_Score 0.8028195820451941

# %% [markdown]
# ### Support Vector Machine Regressor

# %%
# Checking R2 score for Support Vector Machine Regressor
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)

# prediction
predsvr=svr.predict(x_test)
print('R2_Score:',r2_score(y_test,predsvr))
print('MAE:',mean_absolute_error(y_test, predsvr))
print('MSE:',mean_squared_error(y_test, predsvr))
print("RMSE:",np.sqrt(mean_squared_error(y_test, predsvr)))

# Checking cv score for SVR 
print("Cross_Validaton_Score",cross_val_score(svr,x,y,cv=5).mean())
# Out:
# R2_Score: -0.09667313741715544
# MAE: 266.2531059983496
# MSE: 433432.61791435815
# RMSE: 658.3559963381196
# Cross_Validaton_Score -0.14924049784610557

# %% [markdown]
# I select random forest regressor for modelling

# %% [markdown]
# ### Ensembling method

# %% [markdown]
# ### GradientBoostingRegressor

# %%
# Checking R2 score for  GradientBoosting Regressor
from sklearn.ensemble import GradientBoostingRegressor
GB=GradientBoostingRegressor()
GB.fit(x_train,y_train)

# prediction
predGB=GB.predict(x_test)
print('R2_Score:',r2_score(y_test,predGB))
print('MAE:',mean_absolute_error(y_test, predGB))
print('MSE:',mean_squared_error(y_test, predGB))
print("RMSE:",np.sqrt(mean_squared_error(y_test, predGB)))

# Checking cv score for GradientBoosting Regressor
print("Cross_Validaton_Score",cross_val_score(GB,x,y,cv=5).mean())
# Out:
# R2_Score: 0.8972824501321126
# MAE: 103.7459451144355
# MSE: 40596.54150902395
# RMSE: 201.48583451206676
# Cross_Validaton_Score 0.8197202350488807

# %% [markdown]
# ### Bagging Regressor

# %%
from sklearn.ensemble import BaggingRegressor
br=BaggingRegressor()
br.fit(x_train,y_train)

predbr=br.predict(x_test)
print('R2_Score:',r2_score(y_test,predbr))

# Mean Absolute Error (MAE)
print('MAE:',mean_absolute_error(y_test, predbr))

# Mean Squared Error (MSE)
print('MSE:',mean_squared_error(y_test, predbr))

# Root Mean Squared Error (RMSE)
print("RMSE:",np.sqrt(mean_squared_error(y_test, predbr)))

# Checking cv score for BaggingRegressor
print("Cross_Validaton_Score",cross_val_score(br,x,y,cv=5).mean())
# Out:
# R2_Score: 0.8843951514003315
# MAE: 108.1771985001729
# MSE: 45689.9238821125
# RMSE: 213.7520149194213
# Cross_Validaton_Score 0.8006043215348683

# %% [markdown]
# I select GradientBoostingRegressor for ensembling

# %% [markdown]
# ### Hyperparameter tuning

# %%
#RandomForestRegressor
parameters = {'criterion':['mse', 'mae'],
             'max_features':['auto', 'sqrt', 'log2'],
             'n_estimators':[0,200],
             'max_depth':[2,3,4,6]}

# %%
GCV=GridSearchCV(rf,parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': [2, 3, 4, 6],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [0, 200]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 6,
#  'max_features': 'log2',
#  'n_estimators': 200}

# %%
capacity_mw = RandomForestRegressor(criterion='mse', max_depth=6, max_features='log2', n_estimators=200)
capacity_mw.fit(x_train, y_train)
pred = capacity_mw.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print("RMSE value:",np.sqrt(mean_squared_error(y_test, pred_rf)))
# Out:
# R2_Score: 86.8874476891474
# RMSE value: 219.44814368660545

# %% [markdown]
# After HyperParameter Tuning, we are getting an accuracy score of 86.88%

# %% [markdown]
# ### Saving the Model

# %%
# Saving the model using .pkl
import joblib
joblib.dump(capacity_mw,"Global_power_capacity.pkl")
# Out:
# ['Global_power_capacity.pkl']

# %% [markdown]
# ### Predicting the saved model

# %%
# Let's load the saved model and get the prediction

# Loading the saved model
model=joblib.load("Global_power_capacity.pkl")

#Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([2676.31074347,   39.06169197,  688.65265248,   38.92506649,
#          65.94768484,   38.5442318 ,  127.20356556, 1333.91753607,
#          54.01602752,   38.92506649,   99.72225579, 1242.84718734,
#          38.98747726,   20.88314112,  104.07899248,   67.58618306,
#         226.78038243,  108.15358878,  239.36619047,   38.92506649,
#        1312.03224941,   39.57483624,   39.13368988,   38.48292645,
#          20.7571484 ,  113.26125712,   96.15811327,  114.76261002,
#          38.87124757,  100.83789515,  152.15801519,  137.27752629,
#        1296.02286579,  277.09604665,  298.77671736,  116.56126703,
#          21.80017464,   92.99299319,  122.77640153,   87.27839181,
#         110.95455454,   61.08529315,   38.59573529,  425.37977398,
#         128.16179541,  871.09876735,   39.57483624,  121.07855521,
#         112.66068087,  352.97563372,   53.65173492,  425.59859269,
#          67.24700713,  789.01858375,   94.44566487,  117.98088876,
# ...

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                    0          1           2          3          4    \
# Predicted  2676.310743  39.061692  688.652652  38.925066  65.947685
# Original   4000.000000  16.500000  500.000000   6.250000  10.000000
#
#                  5           6            7          8          9    ...  \
# Predicted  38.544232  127.203566  1333.917536  54.016028  38.925066  ...
# Original    1.700000   36.800000  1550.000000   3.750000   5.000000  ...
#
#                   172       173        174         175        176        177  \
# Predicted  139.398943  47.28724  38.987477  111.180528  23.763826  101.56868
# Original    60.000000  12.50000   1.500000   45.000000   2.000000   50.00000
#
#                  178         179         180         181
# Predicted  45.367108  124.141579  120.154834  108.162598
# Original   22.000000  250.000000  130.000000   10.000000
#
# [2 rows x 182 columns]

# %% [markdown]
# ### visualization

# %%
plt.figure(figsize=(8,8))
plt.scatter(y_test, prediction, c='crimson')
plt1 = max(max(prediction), max(y_test))
plt2 = min(min(prediction), min(y_test))
plt.plot([plt1, plt2], [plt1, plt2], 'b-')
plt.title("Random forest Regressor")
plt.xlabel('Actual price', fontsize=15)
plt.ylabel('Predicted price', fontsize=15)
plt.show()

# %% [markdown]
# ### prediction for target 1(Primary Fuel)

# %%
primary_fuel

# %%
X=df.drop('primary_fuel', axis=1)
Y=df["primary_fuel"]

# %%
X.shape
# Out:
# (907, 11)

# %%
Y.shape
# Out:
# (907,)

# %%
Y.nunique()
# Out:
# 8

# %%
Y.dtype
# Out:
# dtype('int32')

# %% [markdown]
# It is classification model as original datatype was categorical data

# %%
X.skew()
# Out:
# capacity_mw             3.123576
# latitude               -0.149698
# longitude               1.163320
# other_fuel1           -20.453120
# commissioning_year     -1.719575
# source                  1.827373
# geolocation_source     -2.159841
# generation_gwh_2014     5.321360
# generation_gwh_2015     5.566773
# generation_gwh_2016     5.281953
# generation_gwh_2017     5.315103
# dtype: float64

# %%
#removing skewness
skew = ['capacity_mw','longitude','other_fuel1','commissioning_year','source','geolocation_source','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017']

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
X[skew] = scaler.fit_transform(X[skew].values)

# %%
X.skew()
# Out:
# capacity_mw             0.022164
# latitude               -0.149698
# longitude               0.002675
# other_fuel1           -17.330022
# commissioning_year     -0.525056
# source                 -0.214066
# geolocation_source     -2.132728
# generation_gwh_2014     0.285906
# generation_gwh_2015     0.222151
# generation_gwh_2016     0.204011
# generation_gwh_2017     0.196816
# dtype: float64

# %% [markdown]
# almost removed skewness

# %%
#Lets visualize the data

plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in X[skew]:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(X[column],color='b',kde_kws={"shade": True},hist=False)
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# ### Scalling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit_transform(X)
X = pd.DataFrame(X,columns=X.columns)
X
# Out:
#      capacity_mw  latitude  longitude  other_fuel1  commissioning_year  \
# 0      -1.695767   28.1839  -0.944854     0.057607            1.113530
# 1       0.193694   24.7663  -0.534212     0.057607            0.053562
# 2      -0.292337   21.9038  -2.390933     0.057607            0.053562
# 3       0.360998   23.8712   2.167755     0.057607            0.346488
# 4       1.649503   21.9603   1.126913     0.057607            1.610143
# ..           ...       ...        ...          ...                 ...
# 902     1.593509   16.2949   0.166816     0.057607            1.741534
# 903    -1.615576   12.8932   0.346098     0.057607            0.053562
# 904    -0.522773   15.2758  -0.268685     0.057607            0.053562
# 905     0.086915   24.3500  -0.787375     0.057607            0.053562
# 906    -0.755891    9.9344   0.194134     0.057607            0.053562
#
#        source  geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# ...

# %%
# Finding varience inflation factor
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(X.values,i)
              for i in range(len(X.columns))]
vif["xm"] = X.columns

# Let's check the values
vif
# Out:
#     VIF values                   xm
# 0     1.815644          capacity_mw
# 1     1.005487             latitude
# 2     1.175790            longitude
# 3     1.033715          other_fuel1
# 4     1.142532   commissioning_year
# 5     1.245271               source
# 6     1.508782   geolocation_source
# 7     4.086407  generation_gwh_2014
# 8     6.853315  generation_gwh_2015
# 9    10.713908  generation_gwh_2016
# 10    5.622860  generation_gwh_2017

# %% [markdown]
# multicoliarity not present

# %% [markdown]
# ### OverSampling

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
X, Y = sm.fit_resample(X,Y)

# %%
Y.value_counts()
# Out:
# 6    258
# 1    258
# 7    258
# 2    258
# 3    258
# 0    258
# 5    258
# 4    258
# Name: primary_fuel, dtype: int64

# %% [markdown]
# ### modelling

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

# %%
# finding best random state
MaxAccu = 0
MaxRS = 0

for i in range(1, 200):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=i)
    dt = DecisionTreeClassifier()
    dt.fit(X_train, Y_train)
    predrf = dt.predict(X_test)
    acc = accuracy_score(Y_test, predrf)
    print('Testing accuracy is', acc, 'Random state is', i)
    if acc > MaxAccu:
        MaxAccu = acc
        MaxRS = i
        
        
print("Maximum accuracy is ", MaxAccu, "Best random state is ", MaxRS)
# Out:
# Testing accuracy is 0.9007263922518159 Random state is 1
# Testing accuracy is 0.8958837772397095 Random state is 2
# Testing accuracy is 0.8861985472154964 Random state is 3
# Testing accuracy is 0.8716707021791767 Random state is 4
# Testing accuracy is 0.8861985472154964 Random state is 5
# Testing accuracy is 0.8789346246973365 Random state is 6
# Testing accuracy is 0.9007263922518159 Random state is 7
# Testing accuracy is 0.8886198547215496 Random state is 8
# Testing accuracy is 0.8813559322033898 Random state is 9
# Testing accuracy is 0.9007263922518159 Random state is 10
# Testing accuracy is 0.8716707021791767 Random state is 11
# Testing accuracy is 0.8837772397094431 Random state is 12
# Testing accuracy is 0.8716707021791767 Random state is 13
# Testing accuracy is 0.8861985472154964 Random state is 14
# Testing accuracy is 0.8692493946731235 Random state is 15
# Testing accuracy is 0.8861985472154964 Random state is 16
# ...

# %% [markdown]
# Maximum accuracy is  0.9249394673123487 Best random state is  47

# %%
#Creating train-test split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=47)

# %% [markdown]
# ### Logistic Regression

# %%
LR=LogisticRegression()
LR.fit(X_train,Y_train)
predLR=LR.predict(X_test)
from sklearn.model_selection import cross_val_score
print(confusion_matrix(Y_test, predLR))
print(classification_report(Y_test,predLR))
print("accuracy :",accuracy_score(Y_test, predLR))
logreg_score=cross_val_score(LR,X_train,Y_train,cv=5,scoring='accuracy')
print("cross validation score:",np.mean(logreg_score))
# Out:
# [[47  0  0  0  0  0  0  1]
#  [ 9 22  6  2  8  3  0  1]
#  [ 0  8 20  6  6 10  0  2]
#  [ 0 12  3 21  3  2  0  6]
#  [ 0  6  0  2 43  0  0  0]
#  [ 1  0  0  0  0 47  0  3]
#  [ 0  2  0  0  0  0 50  0]
#  [ 0  0  1  2  0  0  0 58]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.98      0.90        48
#            1       0.44      0.43      0.44        51
#            2       0.67      0.38      0.49        52
#            3       0.64      0.45      0.52        47
#            4       0.72      0.84      0.77        51
#            5       0.76      0.92      0.83        51
#            6       1.00      0.96      0.98        52
#            7       0.82      0.95      0.88        61
#
#     accuracy                           0.75       413
#    macro avg       0.73      0.74      0.73       413
# weighted avg       0.74      0.75      0.73       413
#
# accuracy : 0.7457627118644068
# cross validation score: 0.7431841069303304

# %% [markdown]
# ### Decision Tree Classifier

# %%
dtc=DecisionTreeClassifier()
dtc_score=cross_val_score(dtc,X,Y,cv=5,scoring='accuracy')

dtc.fit(X_train,Y_train)
predicted_dtc=dtc.predict(X_test)

print(confusion_matrix(Y_test,predicted_dtc))
print(classification_report(Y_test,predicted_dtc))
print("Training accuracy::",dtc.score(X_train,Y_train))
print("Test accuracy::",dtc.score(X_test,Y_test))
print("cross validation score for svm:",np.mean(dtc_score))
print("accuracy",accuracy_score(Y_test,predicted_dtc))
# Out:
# [[47  1  0  0  0  0  0  0]
#  [ 3 39  4  3  2  0  0  0]
#  [ 0  2 45  2  0  3  0  0]
#  [ 0  4  2 41  0  0  0  0]
#  [ 0  1  0  1 49  0  0  0]
#  [ 0  3  3  0  0 45  0  0]
#  [ 0  0  0  0  0  0 52  0]
#  [ 0  0  0  0  0  0  0 61]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        48
#            1       0.78      0.76      0.77        51
#            2       0.83      0.87      0.85        52
#            3       0.87      0.87      0.87        47
#            4       0.96      0.96      0.96        51
#            5       0.94      0.88      0.91        51
#            6       1.00      1.00      1.00        52
#            7       1.00      1.00      1.00        61
#
#     accuracy                           0.92       413
#    macro avg       0.92      0.92      0.92       413
# weighted avg       0.92      0.92      0.92       413
#
# Training accuracy:: 1.0
# Test accuracy:: 0.9176755447941889
# ...

# %% [markdown]
# ### Support Vector Machine Classifier

# %%
svc = SVC()
svc.fit(X_train,Y_train)
predsvc = svc.predict(X_test)
svc_score=cross_val_score(svc,X,Y,cv=5,scoring='accuracy')

print(confusion_matrix(Y_test, predsvc))
print(classification_report(Y_test,predsvc))
print("accuracy" ,accuracy_score(Y_test, predsvc))
print("cross validation score for SVC:",np.mean(svc_score))
# Out:
# [[44  1  0  0  0  0  0  3]
#  [ 9 26  4  1  8  2  0  1]
#  [ 4  9 16  7  4  8  0  4]
#  [ 0  3  6 25  2  4  0  7]
#  [ 0  6  0  6 39  0  0  0]
#  [18  0  0  3  0 27  0  3]
#  [ 2  0  0  0  0  0 50  0]
#  [ 0  0  0  0  0  0  0 61]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.92      0.70        48
#            1       0.58      0.51      0.54        51
#            2       0.62      0.31      0.41        52
#            3       0.60      0.53      0.56        47
#            4       0.74      0.76      0.75        51
#            5       0.66      0.53      0.59        51
#            6       1.00      0.96      0.98        52
#            7       0.77      1.00      0.87        61
#
#     accuracy                           0.70       413
#    macro avg       0.69      0.69      0.68       413
# weighted avg       0.70      0.70      0.68       413
#
# accuracy 0.6973365617433414
# cross validation score for SVC: 0.6753943440137287

# %% [markdown]
# ### KNeighborsClassifier

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
predknn = knn.predict(X_test)
knn_score=cross_val_score(knn,X,Y,cv=5,scoring='accuracy')

print(confusion_matrix(Y_test, predknn))
print(classification_report(Y_test,predknn))
print("cross validation score for knn:",np.mean(knn_score))
print("accuracy",accuracy_score(Y_test,predknn))
# Out:
# [[47  0  0  0  0  1  0  0]
#  [ 7 30  5  0  5  3  0  1]
#  [ 1  5 39  0  2  5  0  0]
#  [ 0  3  3 34  0  1  0  6]
#  [ 0  0  2  0 49  0  0  0]
#  [ 0  0  3  0  0 48  0  0]
#  [ 0  0  0  0  0  0 52  0]
#  [ 0  0  0  0  0  0  0 61]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91        48
#            1       0.79      0.59      0.67        51
#            2       0.75      0.75      0.75        52
#            3       1.00      0.72      0.84        47
#            4       0.88      0.96      0.92        51
#            5       0.83      0.94      0.88        51
#            6       1.00      1.00      1.00        52
#            7       0.90      1.00      0.95        61
#
#     accuracy                           0.87       413
#    macro avg       0.87      0.87      0.86       413
# weighted avg       0.87      0.87      0.87       413
#
# cross validation score for knn: 0.8667540374714967
# accuracy 0.8716707021791767

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc_score=cross_val_score(rfc,X,Y,cv=5,scoring='accuracy')

rfc.fit(X_train,Y_train)
predicted_rfc=rfc.predict(X_test)

print(confusion_matrix(Y_test,predicted_rfc))
print(classification_report(Y_test,predicted_rfc))
print("Training accuracy::",rfc.score(X_train,Y_train))
print("Test accuracy::",rfc.score(X_test,Y_test))
print("cross validation score for random forest classifier:",np.mean(rfc_score))
print("accuracy",accuracy_score(Y_test,predicted_rfc))
# Out:
# [[48  0  0  0  0  0  0  0]
#  [ 4 37  6  1  3  0  0  0]
#  [ 0  4 43  2  0  3  0  0]
#  [ 0  1  1 43  1  1  0  0]
#  [ 0  0  0  0 51  0  0  0]
#  [ 0  1  0  0  0 50  0  0]
#  [ 0  0  0  0  0  0 52  0]
#  [ 0  0  0  0  0  0  0 61]]
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        48
#            1       0.86      0.73      0.79        51
#            2       0.86      0.83      0.84        52
#            3       0.93      0.91      0.92        47
#            4       0.93      1.00      0.96        51
#            5       0.93      0.98      0.95        51
#            6       1.00      1.00      1.00        52
#            7       1.00      1.00      1.00        61
#
#     accuracy                           0.93       413
#    macro avg       0.93      0.93      0.93       413
# weighted avg       0.93      0.93      0.93       413
#
# Training accuracy:: 1.0
# Test accuracy:: 0.9322033898305084
# ...

# %% [markdown]
# ### AdaBoostClassifier

# %%
ad=AdaBoostClassifier()
ad.fit(X_train,Y_train)
predad = ad.predict(X_test)
ad_score=cross_val_score(ad,X,Y,cv=5,scoring='accuracy')

print(confusion_matrix(Y_test, predad))
print(classification_report(Y_test,predad))
print("cross validation score for ad:",np.mean(ad_score))
print("accuracy", accuracy_score(Y_test, predad))
# Out:
# [[48  0  0  0  0  0  0  0]
#  [37 13  0  0  0  1  0  0]
#  [49  3  0  0  0  0  0  0]
#  [39  8  0  0  0  0  0  0]
#  [50  1  0  0  0  0  0  0]
#  [49  0  0  0  0  2  0  0]
#  [ 1  2  0  0  0  0 49  0]
#  [ 0  0  0  0  0 61  0  0]]
#               precision    recall  f1-score   support
#
#            0       0.18      1.00      0.30        48
#            1       0.48      0.25      0.33        51
#            2       0.00      0.00      0.00        52
#            3       0.00      0.00      0.00        47
#            4       0.00      0.00      0.00        51
#            5       0.03      0.04      0.03        51
#            6       1.00      0.94      0.97        52
#            7       0.00      0.00      0.00        61
#
#     accuracy                           0.27       413
#    macro avg       0.21      0.28      0.20       413
# weighted avg       0.21      0.27      0.20       413
#
# cross validation score for ad: 0.2814958038505842
# accuracy 0.2711864406779661

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
# Checking accuracy for Gradient Boosting Classifier
GB = GradientBoostingClassifier()
GB.fit(X_train,Y_train)

# Prediction
predGB = GB.predict(X_test)


print(confusion_matrix(Y_test, predGB))
print(classification_report(Y_test,predGB))
print("cross validation score for ad:",np.mean(ad_score))
print("accuracy",accuracy_score(Y_test, predGB))
# Out:
# [[48  0  0  0  0  0  0  0]
#  [ 4 40  3  0  2  2  0  0]
#  [ 0  2 45  0  1  4  0  0]
#  [ 0  2  3 41  0  1  0  0]
#  [ 0  0  1  0 50  0  0  0]
#  [ 0  1  0  0  0 50  0  0]
#  [ 0  0  0  0  0  0 52  0]
#  [ 0  0  0  0  0  0  0 61]]
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        48
#            1       0.89      0.78      0.83        51
#            2       0.87      0.87      0.87        52
#            3       1.00      0.87      0.93        47
#            4       0.94      0.98      0.96        51
#            5       0.88      0.98      0.93        51
#            6       1.00      1.00      1.00        52
#            7       1.00      1.00      1.00        61
#
#     accuracy                           0.94       413
#    macro avg       0.94      0.94      0.93       413
# weighted avg       0.94      0.94      0.94       413
#
# cross validation score for ad: 0.2814958038505842
# accuracy 0.937046004842615

# %% [markdown]
# ### Hyper parameter tuning for best model

# %% [markdown]
# From the accuracy score and cross validation we can see that Random Forest Classifier is the best model.

# %%
RandomForestClassifier().fit(X_train,Y_train)
parameters = {'n_estimators':[100],
             'criterion':['gini'],
             'max_depth':[2,4,6]}

# %%
GCV=GridSearchCV(rfc,parameters,cv=5)

# %%
GCV.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini'], 'max_depth': [2, 4, 6],
#                          'n_estimators': [100]})

# %%
Final_model=RandomForestClassifier(criterion= 'gini', max_depth= 8, n_estimators= 200,random_state=47)
Final_model.fit(X_train,Y_train)
pred=Final_model.predict(X_test)
acc=accuracy_score(Y_test,pred)
print("accuracy",acc*100)
# Out:
# accuracy 90.79903147699758

# %% [markdown]
# ### roc auc curve

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
fpr1, tpr1, thresh1 = roc_curve(Y_test,pred, pos_label=1)

# %%
#plotting ROC CURVE
sns.set_theme(style="darkgrid")
plt.plot(tpr1, fpr1, linestyle='--',color='red', label='Random Forest classifier')

plt.title('ROC curve')
plt.xlabel('True Positive Rate')
plt.ylabel(' False Positive rate')
plt.legend(loc='best')

# %% [markdown]
# ### saving model

# %%
import joblib
joblib.dump(Final_model,"Global_Power_Plant_Fuel_primary.pkl")
# Out:
# ['Global_Power_Plant_Fuel_primary.pkl']
